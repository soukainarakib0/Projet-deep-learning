# %%
#CHECKS FOR GPU FUNCTIONING
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15231318770265180132
# xla_global_id: -1
# ]

# %%
#Mounting Google Drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Navigating to your base folder
# Create this folder in your drive before running 

# %cd gdrive/My Drive/APM_FINAL #Could be any folder name
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/APM_FINAL #Could be any folder name'
# /content

# %%
# Cloning git repo
! git clone https://github.com/skyler14/ICIAR-histology/ICIAR2018.git
# Out:
# Cloning into 'ICIAR2018'...
# remote: Not Found
# fatal: repository 'https://github.com/skyler14/ICIAR-histology/ICIAR2018.git/' not found
